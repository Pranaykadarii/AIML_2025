# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranaykadarii/AIML_2025/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import necessary libraries
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
#Step 1:Load the Iris dataset
iris = load_iris()

# %%
X=iris.data #Features

# %%
Y=iris.target #Labels

# %%
#Step 2:preprocess the data (standardization)
scaler=StandardScaler()

# %%
X_scaled=scaler.fit_transform(X)

# %%
#Step 3: Apply PCA to reduce to 2 dimensions
pca=PCA(n_components=2)

# %%
X_pca=pca.fit_transform(X_scaled)

# %%
#Step 4: visualize the reduced features (2D scatter plot)
plt.figure(figsize=(8,6))

# %%
plt.scatter(X_pca[:,0],X_pca[:,1],c=Y,cmap='viridis',edgecolor='k',s=100)
plt.title('PCA of iris Dataset (2 Components)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('2D Scatter Plot of Reduced Features')
plt.colorbar(label='Class')
plt.show()

# %%
#Optional: Explained Variance Ratio
print("Explained variance Ratio of Each Component:")
print('pca.explained_variance_ratio')
# Out:
# Explained variance Ratio of Each Component:
# pca.explained_variance_ratio
